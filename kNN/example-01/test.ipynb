# %% [markdown]
# # My first use in Jupyter

# %% [markdown]
# ## I am so happy

# %% [markdown]
# This is an add example:

# %%
b=1+3

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# $$\int_0^{+\infty} x^2 dx$$

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.arange(20)
y=x**3

plt.plot(x,y)

# %%
a = 123

# %%
print(a)
# Out:
# 123

# %%
b
# Out:
# 4
